# %%
#Logistic Regression

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("titanic_cleaned.csv")

# %%
df.head(5)
# Out:
#    Unnamed: 0  survived  pclass  sex       age  sibsp  parch      fare  \
# 0           0         0       3    1 -0.528042      1      0 -0.528042
# 1           1         1       1    0  0.561708      1      0  0.561708
# 2           2         1       3    0 -0.255604      0      0 -0.255604
# 3           3         1       1    0  0.357380      1      0  0.357380
# 4           4         0       3    1  0.357380      0      0  0.357380
#
#    adult_male  alive  alone  embarked_Q  embarked_S  class_Second  \
# 0           1      0      0           0           1             0
# 1           0      1      0           0           0             0
# 2           0      1      1           0           1             0
# 3           0      1      0           0           1             0
# 4           1      0      1           0           1             0
#
#    class_Third  who_man  who_woman  embark_town_Queenstown  \
# 0            1        1          0                       0
# 1            0        0          1                       0
# 2            1        0          1                       0
# 3            0        0          1                       0
# 4            1        1          0                       0
#
#    embark_town_Southampton
# 0                        1
# 1                        0
# 2                        1
# 3                        1
# 4                        1

# %%
df=df.drop("Unnamed: 0",axis=1)

# %%
df.sample(5)
# Out:
#      survived  pclass  sex       age  sibsp  parch      fare  adult_male  \
# 275         0       3    0 -0.391823      0      0 -0.391823           0
# 601         0       3    1 -1.072916      5      2 -1.072916           0
# 752         1       3    0 -0.391823      0      3 -0.391823           0
# 256         0       1    1  0.493599      0      1  0.493599           1
# 108         0       3    1 -0.596151      0      0 -0.596151           1
#
#      alive  alone  embarked_Q  embarked_S  class_Second  class_Third  who_man  \
# 275      0      1           0           1             0            1        0
# 601      0      0           0           1             0            1        0
# 752      1      0           0           0             0            1        0
# 256      0      0           0           0             0            0        1
# 108      0      1           0           1             0            1        1
#
#      who_woman  embark_town_Queenstown  embark_town_Southampton
# 275          1                       0                        1
# 601          0                       0                        1
# 752          1                       0                        0
# 256          0                       0                        0
# 108          0                       0                        1

# %%
df.isnull().sum()
# Out:
# survived                     0
# pclass                       0
# sex                          0
# age                        104
# sibsp                        0
# parch                        0
# fare                       104
# adult_male                   0
# alive                        0
# alone                        0
# embarked_Q                   0
# embarked_S                   0
# class_Second                 0
# class_Third                  0
# who_man                      0
# who_woman                    0
# embark_town_Queenstown       0
# embark_town_Southampton      0
# dtype: int64

# %%
df['age'] = df['age'].fillna(df['age'].mean())
df['fare'] = df['fare'].fillna(df['fare'].mean())

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()

# %%
X=df.drop("survived",axis=1)
y=df['survived']

# %%
X=X.drop("alive",axis=1)

# %%
X.head()
# Out:
#    pclass  sex       age  sibsp  parch      fare  adult_male  alone  \
# 0       3    1 -0.528042      1      0 -0.528042           1      0
# 1       1    0  0.561708      1      0  0.561708           0      0
# 2       3    0 -0.255604      0      0 -0.255604           0      1
# 3       1    0  0.357380      1      0  0.357380           0      0
# 4       3    1  0.357380      0      0  0.357380           1      1
#
#    embarked_Q  embarked_S  class_Second  class_Third  who_man  who_woman  \
# 0           0           1             0            1        1          0
# 1           0           0             0            0        0          1
# 2           0           1             0            1        0          1
# 3           0           1             0            0        0          1
# 4           0           1             0            1        1          0
#
#    embark_town_Queenstown  embark_town_Southampton
# 0                       0                        1
# 1                       0                        0
# 2                       0                        1
# 3                       0                        1
# 4                       0                        1

# %%
y.head()
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: survived, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy=accuracy_score(y_test,y_pred)

# %%
accuracy
# Out:
# 0.782051282051282

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.87      0.82        87
#            1       0.81      0.67      0.73        69
#
#     accuracy                           0.78       156
#    macro avg       0.79      0.77      0.77       156
# weighted avg       0.79      0.78      0.78       156
